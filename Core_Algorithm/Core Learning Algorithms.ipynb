# %% [markdown]
# TensorFlow Core Learning Algorithms
# - linear Regression
# - Classification
# - Clustering
# - Hidden Markov Model

# %% [markdown]
# Linear Regression

# %%
x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x,y, 'ro')
plt.axis([0,6,0,20])

# %% [markdown]
# Linear Coorespodence

# %%
plt.plot(x,y, 'ro')
plt.axis([0,6,0,20])
plt.plot(np.unique(x), np.poly1d(np.polyfit(x,y,1))(np.unique(x)))
