# %% [markdown]
# # Clustering

# %% [markdown]
# k-means
# - Randomly pick k points to place k centroid
# - assign all of the data points to centroid by distance
# - average all of the points belogging to each centrioid to find the mittle of those clusters. Place the corresponding centroids into that position
# - Reassign every point once again to the closest centroid
# - Repeat steps 3-4 untill no point changes which centroid it belongs to
